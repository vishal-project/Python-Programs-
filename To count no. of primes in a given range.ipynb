# %%
# COUNT PRIMES: Write a function that returns the number of prime numbers that exist up to and including a given number.

def count_primes(num):
    c=0
    for i in range(2,num+1):
        for n in range(2,i):
            if i%n==0:
                print(f" not prime {i}")         # not prime
                break
               
        else:
             
            print(f"prime {i}") # prime 
            c=c+1
    return f"Total no. of prime numbers are {c} between 1 to {num}."

print(count_primes(100))
# Out:
# prime 2
# prime 3
#  not prime 4
# prime 5
#  not prime 6
# prime 7
#  not prime 8
#  not prime 9
#  not prime 10
# prime 11
#  not prime 12
# prime 13
#  not prime 14
#  not prime 15
#  not prime 16
# prime 17
#  not prime 18
# prime 19
#  not prime 20
#  not prime 21
#  not prime 22
# prime 23
#  not prime 24
#  not prime 25
#  not prime 26
#  not prime 27
#  not prime 28
# prime 29
#  not prime 30
# prime 31
#  not prime 32
#  not prime 33
#  not prime 34
#  not prime 35
#  not prime 36
# prime 37
#  not prime 38
#  not prime 39
#  not prime 40
# prime 41
#  not prime 42
# prime 43
#  not prime 44
#  not prime 45
#  not prime 46
# prime 47
#  not prime 48
#  not prime 49
#  not prime 50
#  not prime 51
#  not prime 52
# prime 53
#  not prime 54
#  not prime 55
#  not prime 56
#  not prime 57
#  not prime 58
# prime 59
#  not prime 60
# prime 61
#  not prime 62
#  not prime 63
#  not prime 64
#  not prime 65
#  not prime 66
# prime 67
#  not prime 68
#  not prime 69
#  not prime 70
# prime 71
#  not prime 72
# prime 73
#  not prime 74
#  not prime 75
#  not prime 76
#  not prime 77
#  not prime 78
# prime 79
#  not prime 80
#  not prime 81
#  not prime 82
# prime 83
#  not prime 84
#  not prime 85
#  not prime 86
#  not prime 87
#  not prime 88
# prime 89
#  not prime 90
#  not prime 91
#  not prime 92
#  not prime 93
#  not prime 94
#  not prime 95
#  not prime 96
# prime 97
#  not prime 98
#  not prime 99
#  not prime 100
# Total no. of prime numbers are 25 between 1 to 100.
